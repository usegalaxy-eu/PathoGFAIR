# %%
from bioblend.galaxy import GalaxyInstance
import pandas as pd
from io import StringIO
import os
import requests

# %% [markdown]
# # Add galaxy API key
# Add `GALAXY_API_KEY` from `https://usegalaxy.eu/user/api_key` via `export GALAXY_API_KEY="<key>"` or `%env  GALAXY_API_KEY=<key>` in jupyter

# %%
# %env GALAXY_API_KEY=
# Out:
# env: GALAXY_API_KEY=cf4092f19ab187b157fea51f97f2791b

# %%
gi = GalaxyInstance(url='https://usegalaxy.eu/', key=os.environ['GALAXY_API_KEY'])

history = gi.histories.show_history('c6a065584d5bc954', contents=True)

# %%
data_lookup = {
    "VF":'VFs of genes',
    "AMR":'AMR Identifiied'
} #lookup with a part of the name of the files that should be collected

def get_summary_of_history(history, data_lookup):
        
    summary_df = pd.DataFrame()

    for dataset in history:
        if 'tags' in dataset:
            tags = '/'.join(dataset['tags'])
        else:
            tags = 'no tag'

        name = dataset['name']

        for short_name, lookup in data_lookup.items():

            if lookup in name:
                print(name, tags)
                try:
                    data = gi.datasets.download_dataset(dataset['id'], maxwait = 3)

                    df = pd.read_csv(StringIO(data.decode("utf-8")), sep="\t")

                    summary_df.loc[tags, short_name] = len(df)

                except:
                    pass


    return(summary_df)

# %%
summary_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-170-418ba36bdeb3> in <module>
# ----> 1 summary_df
#
# NameError: name 'summary_df' is not defined

# %% [markdown]
# # Plot for multiple histories

# %%
history_links = {
    "pure 01":"https://usegalaxy.eu/u/engy.nasr/h/paper-data-analysis-pure-pathogens-on-10052022",
    "pure 02":"https://usegalaxy.eu/u/engy.nasr/h/paper-data-analysis-pure-pathogens-17022022-1",
    "spiked 01":"https://usegalaxy.eu/u/engy.nasr/h/paper-data-analysis-biolytix-datasets-on-19062022-spiked",
    "spiked 02":"https://usegalaxy.eu/u/engy.nasr/h/paper-data-analysis-biolytix-datasets-on-14072022-spiked",
    "spiked 03":"https://usegalaxy.eu/u/engy.nasr/h/paper-data-analysis-biolytix-datasets-on-20072022-spiked",
    "spiked and depletion 01":"https://usegalaxy.eu/u/engy.nasr/h/paper-data-analysis-biolytix-datasets-on-18082022-spiked---enrichment-for-salmonella-sequences",
    "spiked and depletion 02":"https://usegalaxy.eu/u/engy.nasr/h/paper-data-analysis-biolytix-datasets-on-18082022-spiked---chicken-depletion",
    "dilution": "https://usegalaxy.eu/u/engy.nasr/h/latest-datasets-with-the-latest-workflows-1",
}

for category, history_link in history_links.items():
    
    print('*******************************')
    print(category, history_link)
    
    url = requests.get(history_link).url #follow link to get id
    history_id = url.split("=")[-1]
    
    history = gi.histories.show_history(history_id, contents=True)
    summary_df = get_summary_of_history(history, data_lookup)
    print(summary_df)
# Out:
# *******************************
# pure 01 https://usegalaxy.eu/u/engy.nasr/h/paper-data-analysis-pure-pathogens-on-10052022
# Empty DataFrame
# Columns: []
# Index: []
# *******************************
# pure 02 https://usegalaxy.eu/u/engy.nasr/h/paper-data-analysis-pure-pathogens-17022022-1
# AMR Identifiied by NCBI name:Barcode01
# VFs of genes Identified by VFDB name:Barcode01
# AMR Identifiied by NCBI name:Barcode02
# VFs of genes Identified by VFDB name:Barcode02
# AMR Identifiied by NCBI name:Barcode03
# VFs of genes Identified by VFDB name:Barcode03
# AMR Identifiied by NCBI name:Barcode04
# VFs of genes Identified by VFDB name:Barcode04
# AMR Identifiied by NCBI name:Barcode05
# VFs of genes Identified by VFDB name:Barcode05
# AMR Identifiied by NCBI name:Barcode07
# VFs of genes Identified by VFDB name:Barcode07
# AMR Identifiied by NCBI name:Barcode08
# VFs of genes Identified by VFDB name:Barcode08
# AMR Identifiied by NCBI name:Barcode09
# VFs of genes Identified by VFDB name:Barcode09
#                 AMR     VF
# name:Barcode01  0.0   86.0
# name:Barcode02  5.0  135.0
# name:Barcode03  0.0   98.0
# name:Barcode04  0.0  107.0
# name:Barcode05  1.0   90.0
# name:Barcode07  2.0   34.0
# name:Barcode08  2.0   41.0
# name:Barcode09  0.0   13.0
# *******************************
# spiked 01 https://usegalaxy.eu/u/engy.nasr/h/paper-data-analysis-biolytix-datasets-on-19062022-spiked
# Empty DataFrame
# Columns: []
# Index: []
# *******************************
# spiked 02 https://usegalaxy.eu/u/engy.nasr/h/paper-data-analysis-biolytix-datasets-on-14072022-spiked
# Empty DataFrame
# Columns: []
# Index: []
# *******************************
# spiked 03 https://usegalaxy.eu/u/engy.nasr/h/paper-data-analysis-biolytix-datasets-on-20072022-spiked
# Empty DataFrame
# Columns: []
# Index: []
# *******************************
# spiked and depletion 01 https://usegalaxy.eu/u/engy.nasr/h/paper-data-analysis-biolytix-datasets-on-18082022-spiked---enrichment-for-salmonella-sequences
# AMR Identifiied by NCBI name:Barcode10-Enrichment
# VFs of genes Identified by VFDB name:Barcode10-Enrichment
# AMR Identifiied by NCBI name:Barcode11-Enrichment
# VFs of genes Identified by VFDB name:Barcode11-Enrichment
# AMR Identifiied by NCBI name:Barcode12-Enrichment
# VFs of genes Identified by VFDB name:Barcode12-Enrichment
# AMR Identifiied by NCBI name:Barcode13-WithoutEnrichment
# VFs of genes Identified by VFDB name:Barcode13-WithoutEnrichment
# AMR Identifiied by NCBI name:Barcode14-WithoutEnrichment
# VFs of genes Identified by VFDB name:Barcode14-WithoutEnrichment
#                                   AMR    VF
# name:Barcode10-Enrichment         3.0   6.0
# name:Barcode11-Enrichment         0.0  78.0
# name:Barcode12-Enrichment         0.0  73.0
# name:Barcode13-WithoutEnrichment  0.0   0.0
# *******************************
# spiked and depletion 02 https://usegalaxy.eu/u/engy.nasr/h/paper-data-analysis-biolytix-datasets-on-18082022-spiked---chicken-depletion
# Empty DataFrame
# Columns: []
# Index: []
# *******************************
# dilution https://usegalaxy.eu/u/engy.nasr/h/latest-datasets-with-the-latest-workflows-1
# AMR Identifiied by NCBI name:Barcode01
# VFs of genes Identified by VFDB name:Barcode01
# AMR Identifiied by NCBI name:Barcode02
# VFs of genes Identified by VFDB name:Barcode02
# AMR Identifiied by NCBI name:Barcode03
# VFs of genes Identified by VFDB name:Barcode03
# AMR Identifiied by NCBI name:Barcode04
# VFs of genes Identified by VFDB name:Barcode04
# AMR Identifiied by NCBI name:Barcode05
# VFs of genes Identified by VFDB name:Barcode05
# AMR Identifiied by NCBI name:Barcode06
# VFs of genes Identified by VFDB name:Barcode06
# AMR Identifiied by NCBI name:Barcode07
# VFs of genes Identified by VFDB name:Barcode07
# AMR Identifiied by NCBI name:Barcode08
# VFs of genes Identified by VFDB name:Barcode08
# AMR Identifiied by NCBI name:Barcode09
# VFs of genes Identified by VFDB name:Barcode09
# AMR Identifiied by NCBI name:Barcode10
# VFs of genes Identified by VFDB name:Barcode10
# AMR Identifiied by NCBI name:Barcode11
# VFs of genes Identified by VFDB name:Barcode11
# AMR Identifiied by NCBI name:Barcode12
# VFs of genes Identified by VFDB name:Barcode12
# AMR Identifiied by NCBI name:Barcode13
# VFs of genes Identified by VFDB name:Barcode13
# AMR Identifiied by NCBI name:Barcode14
# VFs of genes Identified by VFDB name:Barcode14
# AMR Identifiied by NCBI name:Barcode15
# VFs of genes Identified by VFDB name:Barcode15
# AMR Identifiied by NCBI name:Barcode16
# VFs of genes Identified by VFDB name:Barcode16
# AMR Identifiied by NCBI name:unclassified
# VFs of genes Identified by VFDB name:unclassified
#                    AMR    VF
# name:Barcode01     3.0  65.0
# name:Barcode02     3.0   0.0
# name:Barcode03     0.0   0.0
# name:Barcode04     0.0   0.0
# name:Barcode05     0.0   0.0
# name:Barcode06     0.0   0.0
# name:Barcode07     0.0   0.0
# name:Barcode08     0.0   0.0
# name:Barcode10     0.0   0.0
# name:Barcode11     0.0   0.0
# name:Barcode12     0.0   0.0
# name:Barcode13     0.0   0.0
# name:Barcode14     0.0   0.0
# name:Barcode15     0.0   0.0
# name:Barcode16     0.0   0.0
# name:unclassified  0.0   0.0

# %% [markdown]
# # Plot taxonomy

# %%
history_link = "https://usegalaxy.eu/published/history?id=a90a5dd2a4c17493"

url = requests.get(history_link).url #follow link to get id
history_id = url.split("=")[-1]

history = gi.histories.show_history(history_id, contents=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5f6fe25ba088> in <module>
#       4 history_id = url.split("=")[-1]
#       5
# ----> 6 history = gi.histories.show_history(history_id, contents=True)
#       7
#
# NameError: name 'gi' is not defined

# %%
look_up = "Kraken"

for dataset in history:

    name = dataset['name']

    if look_up in name:
        if dataset["history_content_type"] = "dataset_collection"
            print(dataset)
            break

# %% [markdown]
# # Plot using collections

# %%
gi = GalaxyInstance(url='https://usegalaxy.eu/', key=os.environ['GALAXY_API_KEY'])
history = gi.histories.show_history('a90a5dd2a4c17493', contents=True)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-6-b15982e31492> in <module>
#       1 gi = GalaxyInstance(url='https://usegalaxy.eu/', key=os.environ['GALAXY_API_KEY'])
# ----> 2 history = gi.histories.show_history('a90a5dd2a4c17493', contents=True)
#
# ~/mambaforge/envs/galaxy-api/lib/python3.7/site-packages/bioblend/galaxy/histories/__init__.py in show_history(self, history_id, contents, deleted, visible, details, types)
#     287             if types is not None:
#     288                 params["types"] = types
# --> 289         return self._get(id=history_id, contents=contents, params=params)
#     290
#     291     def delete_dataset(self, history_id: str, dataset_id: str, purge: bool = False) -> None:
#
# ~/mambaforge/envs/galaxy-api/lib/python3.7/site-packages/bioblend/galaxy/client.py in _get(self, id, deleted, contents, url, params, json)
#     135                     msg,
#     136                     body=r.text,
# --> 137                     status_code=r.status_code,
#     138                 )
#     139             else:
#
# ConnectionError: GET: error 504: b'<!DOCTYPE html>\n<html>\n\n   <head>\n      <title>Galaxy Europe, error page</title>\n      <link rel="canonical" href="https://usegalaxy-eu.github.io/error_pages/503.html">\n   </head>\t\n   <body>\n     <iframe src="https://usegalaxy-eu.github.io/error_pages/503.html" style="position:fixed; top:0; left:0; bottom:0; right:0; width:100%; height:100%; border:none; margin:0; padding:0; overflow:hidden; z-index:999999;">\n        <a href="https://usegalaxy-eu.github.io/error_pages/503.html">503</a>\n     </iframe>      \n   </body>\t\n</html>\n', 0 attempts left: <!DOCTYPE html>
# <html>
#
#    <head>
#       <title>Galaxy Europe, error page</title>
#       <link rel="canonical" href="https://usegalaxy-eu.github.io/error_pages/503.html">
#    </head>
#    <body>
#      <iframe src="https://usegalaxy-eu.github.io/error_pages/503.html" style="position:fixed; top:0; left:0; bottom:0; right:0; width:100%; height:100%; border:none; margin:0; padding:0; overflow:hidden; z-index:999999;">
#         <a href="https://usegalaxy-eu.github.io/error_pages/503.html">503</a>
#      </iframe>
#    </body>
# </html>

# %%
collection_name = "Kraken2 with Kalamri database Report"
history_id = "1b1e3a724f08cb2b"
datasets = gi.datasets.get_datasets(name = collection_name, history_id = history_id)

lookups = [
"d__Bacteria|p__Proteobacteria|c__Gammaproteobacteria|o__Enterobacterales|f__Enterobacteriaceae|g__Salmonella"
]

#fetch collection by name
if len(datasets) > 1:
    print("too many datasets with that name")

for dataset in datasets:
    if dataset['history_content_type']=='dataset_collection':
        print(dataset)
        dataset_collection_id = dataset["id"]

lookup_count = {}

# get data of the elements in the collection
collection = gi.dataset_collections.show_dataset_collection(dataset_collection_id = dataset_collection_id)
for element in collection['elements']:

    element_name = element['element_identifier']
    element_id = element['object']['id']
    data = gi.datasets.download_dataset(element_id, maxwait = 3)
    df = pd.read_csv(StringIO(data.decode("utf-8")), sep="\t", header=None)

    lookup_counts = {}
    for lookup in lookups:
        # print(lookup)
        # print(df.loc[df[0].str.contains(lookup),1])
        if df.loc[df[0].str.contains(lookup),1].empty:
            num_of_lookup = 0
        else:    
            num_of_lookup = int(df.loc[df[0].str.contains(lookup),1])
        lookup_counts[lookup] = num_of_lookup

    lookup_count[element_name] = lookup_counts
    print(element_name, lookup_counts)
# Out:
# too many datasets with that name
# {'tags': [], 'job_source_type': 'ImplicitCollectionJobs', 'type': 'collection', 'id': '513ece2bf9833344', 'history_content_type': 'dataset_collection', 'job_state_summary': {'resubmitted': 0, 'queued': 0, 'ok': 50, 'error': 0, 'paused': 0, 'deleted': 0, 'upload': 0, 'new': 0, 'waiting': 0, 'running': 0, 'failed': 0, 'skipped': 0, 'deleted_new': 0, 'all_jobs': 50}, 'url': '*deprecated attribute, URL not filled in by server*', 'deleted': False, 'populated_state_message': None, 'type_id': 'dataset_collection-513ece2bf9833344', 'job_source_id': 'f0f53f60b0c39816', 'create_time': '2023-05-11T06:55:59.585549', 'history_id': '1b1e3a724f08cb2b', 'populated_state': 'ok', 'collection_type': 'list', 'collection_id': 6746613, 'contents_url': '/api/dataset_collections/513ece2bf9833344/contents/3dc61ad9c4d6d626', 'element_count': 50, 'update_time': '2023-05-11T06:55:59.585550', 'visible': True, 'name': 'Kraken2 with Kalamri database Report', 'hid': 919}
# Spike4Unclassified {'Salmonella houtenae': 0, 'Salmonella enterica': 1160, 'Salmonella salamae': 0}
# Spike4Barcode16 {'Salmonella houtenae': 0, 'Salmonella enterica': 3892, 'Salmonella salamae': 0}
# Spike4Barcode15 {'Salmonella houtenae': 0, 'Salmonella enterica': 8304, 'Salmonella salamae': 0}
# Spike4Barcode14 {'Salmonella houtenae': 0, 'Salmonella enterica': 734, 'Salmonella salamae': 0}
# Spike4Barcode13 {'Salmonella houtenae': 0, 'Salmonella enterica': 1176, 'Salmonella salamae': 0}
# Spike4Barcode12 {'Salmonella houtenae': 0, 'Salmonella enterica': 28, 'Salmonella salamae': 0}
# Spike4Barcode11 {'Salmonella houtenae': 0, 'Salmonella enterica': 24, 'Salmonella salamae': 0}
# Spike4Barcode10 {'Salmonella houtenae': 0, 'Salmonella enterica': 29, 'Salmonella salamae': 0}
# Spike4Barcode09 {'Salmonella houtenae': 0, 'Salmonella enterica': 84, 'Salmonella salamae': 0}
# Spike4Barcode08 {'Salmonella houtenae': 0, 'Salmonella enterica': 24, 'Salmonella salamae': 0}
# Spike4Barcode07 {'Salmonella houtenae': 0, 'Salmonella enterica': 18, 'Salmonella salamae': 0}
# Spike4Barcode06 {'Salmonella houtenae': 0, 'Salmonella enterica': 11, 'Salmonella salamae': 0}
# Spike4Barcode05 {'Salmonella houtenae': 0, 'Salmonella enterica': 56, 'Salmonella salamae': 0}
# Spike4Barcode04 {'Salmonella houtenae': 0, 'Salmonella enterica': 55, 'Salmonella salamae': 0}
# Spike4Barcode03 {'Salmonella houtenae': 0, 'Salmonella enterica': 59, 'Salmonella salamae': 0}
# Spike4Barcode02 {'Salmonella houtenae': 0, 'Salmonella enterica': 1379, 'Salmonella salamae': 0}
# Spike4Barcode01 {'Salmonella houtenae': 0, 'Salmonella enterica': 12412, 'Salmonella salamae': 0}
# Spike3bUnclassified {'Salmonella houtenae': 0, 'Salmonella enterica': 1259, 'Salmonella salamae': 0}
# Spike3bBarcode15 {'Salmonella houtenae': 0, 'Salmonella enterica': 53, 'Salmonella salamae': 0}
# Spike3bBarcode14 {'Salmonella houtenae': 0, 'Salmonella enterica': 163, 'Salmonella salamae': 0}
# Spike3bBarcode13 {'Salmonella houtenae': 0, 'Salmonella enterica': 80, 'Salmonella salamae': 0}
# Spike3bBarcode12 {'Salmonella houtenae': 0, 'Salmonella enterica': 1954, 'Salmonella salamae': 0}
# Spike3bBarcode11 {'Salmonella houtenae': 0, 'Salmonella enterica': 5552, 'Salmonella salamae': 0}
# Spike3bBarcode10 {'Salmonella houtenae': 0, 'Salmonella enterica': 2764, 'Salmonella salamae': 0}
# Spike3Unclassified {'Salmonella houtenae': 0, 'Salmonella enterica': 207, 'Salmonella salamae': 0}
# Spike3Barcode15 {'Salmonella houtenae': 0, 'Salmonella enterica': 24, 'Salmonella salamae': 0}
# Spike3Barcode14 {'Salmonella houtenae': 0, 'Salmonella enterica': 56, 'Salmonella salamae': 0}
# Spike3Barcode13 {'Salmonella houtenae': 0, 'Salmonella enterica': 25, 'Salmonella salamae': 0}
# Spike3Barcode12 {'Salmonella houtenae': 0, 'Salmonella enterica': 561, 'Salmonella salamae': 0}
# Spike3Barcode11 {'Salmonella houtenae': 0, 'Salmonella enterica': 1606, 'Salmonella salamae': 0}
# Spike3Barcode10 {'Salmonella houtenae': 0, 'Salmonella enterica': 746, 'Salmonella salamae': 0}
# Spike2bUnclassified {'Salmonella houtenae': 0, 'Salmonella enterica': 5881, 'Salmonella salamae': 0}
# Spike2bBarcode15 {'Salmonella houtenae': 0, 'Salmonella enterica': 401, 'Salmonella salamae': 0}
# Spike2bBarcode14 {'Salmonella houtenae': 0, 'Salmonella enterica': 686, 'Salmonella salamae': 0}
# Spike2bBarcode13 {'Salmonella houtenae': 0, 'Salmonella enterica': 630, 'Salmonella salamae': 0}
# Spike2bBarcode12 {'Salmonella houtenae': 0, 'Salmonella enterica': 6162, 'Salmonella salamae': 0}
# Spike2bBarcode11 {'Salmonella houtenae': 0, 'Salmonella enterica': 17330, 'Salmonella salamae': 0}
# Spike2bBarcode10 {'Salmonella houtenae': 0, 'Salmonella enterica': 17965, 'Salmonella salamae': 0}
# Spike2Barcode15 {'Salmonella houtenae': 0, 'Salmonella enterica': 14, 'Salmonella salamae': 0}
# Spike2Barcode14 {'Salmonella houtenae': 0, 'Salmonella enterica': 236, 'Salmonella salamae': 0}
# Spike2Barcode13 {'Salmonella houtenae': 0, 'Salmonella enterica': 29, 'Salmonella salamae': 0}
# Spike2Barcode12 {'Salmonella houtenae': 0, 'Salmonella enterica': 3587, 'Salmonella salamae': 0}
# Spike2Barcode11 {'Salmonella houtenae': 0, 'Salmonella enterica': 13088, 'Salmonella salamae': 0}
#  Spike2Barcode10 {'Salmonella houtenae': 0, 'Salmonella enterica': 10632, 'Salmonella salamae': 0}
# Spike1Barcode15 {'Salmonella houtenae': 0, 'Salmonella enterica': 17, 'Salmonella salamae': 0}
# Spike1Barcode14 {'Salmonella houtenae': 0, 'Salmonella enterica': 136, 'Salmonella salamae': 0}
# Spike1Barcode13 {'Salmonella houtenae': 0, 'Salmonella enterica': 21, 'Salmonella salamae': 0}
# Spike1Barcode12 {'Salmonella houtenae': 0, 'Salmonella enterica': 867, 'Salmonella salamae': 0}
# Spike1Barcode11 {'Salmonella houtenae': 0, 'Salmonella enterica': 11225, 'Salmonella salamae': 0}
# Spike1Barcode10 {'Salmonella houtenae': 0, 'Salmonella enterica': 10282, 'Salmonella salamae': 0}

# %%
dataset_lookup = "Salmonella enterica"
int(df.loc[df[0].str.contains(dataset_lookup),1])
# Out:
# 1160

# %%
df = pd.DataFrame(lookup_count.items())
df.set_index(0, inplace=True)
df.index.name = "Name"
df.columns = ["Count"]
# Out:
#                      Count
# Name
# Spike4Unclassified    1160
# Spike4Barcode16       3892
# Spike4Barcode15       8304
# Spike4Barcode14        734
# Spike4Barcode13       1176
# Spike4Barcode12         28
# Spike4Barcode11         24
# Spike4Barcode10         29
# Spike4Barcode09         84
# Spike4Barcode08         24
# Spike4Barcode07         18
# Spike4Barcode06         11
# Spike4Barcode05         56
# Spike4Barcode04         55
# Spike4Barcode03         59
# Spike4Barcode02       1379
# Spike4Barcode01      12412
# Spike3bUnclassified   1259
# Spike3bBarcode15        53
# Spike3bBarcode14       163
# Spike3bBarcode13        80
# Spike3bBarcode12      1954
# Spike3bBarcode11      5552
# Spike3bBarcode10      2764
# Spike3Unclassified     207
# Spike3Barcode15         24
# Spike3Barcode14         56
# Spike3Barcode13         25
# Spike3Barcode12        561
# Spike3Barcode11       1606
# Spike3Barcode10        746
# Spike2bUnclassified   5881
# Spike2bBarcode15       401
# Spike2bBarcode14       686
# Spike2bBarcode13       630
# Spike2bBarcode12      6162
# Spike2bBarcode11     17330
# Spike2bBarcode10     17965
# Spike2Barcode15         14
# Spike2Barcode14        236
# Spike2Barcode13         29
# Spike2Barcode12       3587
# Spike2Barcode11      13088
#  Spike2Barcode10     10632
# Spike1Barcode15         17
# Spike1Barcode14        136
# Spike1Barcode13         21
# Spike1Barcode12        867
# Spike1Barcode11      11225
# Spike1Barcode10      10282

# %% [markdown]
# # Collection of AMR, VR counts

# %%
def get_summary_of_collection(gi, collection_name, history_id, column_name):
    """
    Collects the counts of datasets in a collection
    """

    datasets = gi.datasets.get_datasets(name = collection_name, history_id = history_id)

    #print(datasets)

    #fetch collection by name
    if len(datasets) > 1:
        print("too many datasets with that name")

    for dataset in datasets:
        if dataset['history_content_type']=='dataset_collection': #get only collections
            if dataset['job_state_summary']['all_jobs'] == dataset['job_state_summary']['ok']: #get only collections where all jobs are ok
                dataset_collection_id = dataset["id"]

    look_up = {}
    # get data of the elements in the collection
    collection = gi.dataset_collections.show_dataset_collection(dataset_collection_id = dataset_collection_id)
    for element in collection['elements']:

        element_name = element['element_identifier']
        element_id = element['object']['id']
        data = gi.datasets.download_dataset(element_id, maxwait = 3)
        df = pd.read_csv(StringIO(data.decode("utf-8")), sep="\t")

        look_up[element_name] = len(df)
        print(element_name, len(df))

    df = pd.DataFrame(look_up.items())
    df.set_index(0, inplace=True)
    df.index.name = "Name"
    df.columns = [column_name]

    return(df)

# %% [markdown]
# # Get df for AMR and VF

# %%
gi = GalaxyInstance(url='https://usegalaxy.eu/', key=os.environ['GALAXY_API_KEY'])

collection_name = "VFs of genes Identified by VFDB"
history_id = "a90a5dd2a4c17493"
column_name = "VFs"

VF_df = get_summary_of_collection(gi, collection_name, history_id, column_name)

collection_name = "AMR Identifiied by NCBI"
history_id = "a90a5dd2a4c17493"
column_name = "AMR"

AMR_df = get_summary_of_collection(gi, collection_name, history_id, column_name)
# Out:
# too many datasets with that name
# Spike1Barcode10 121
# Spike1Barcode11 60
# Spike1Barcode12 0
# Spike1Barcode13 0
# Spike1Barcode14 0
# Spike1Barcode15 0
#  Spike2Barcode10 135
# Spike2Barcode11 97
# Spike2Barcode12 77
# Spike2Barcode13 0
# Spike2Barcode14 0
# Spike2Barcode15 0
# Spike2bBarcode10 175
# Spike2bBarcode11 97
# Spike2bBarcode12 84
# Spike2bBarcode13 0
# Spike2bBarcode14 0
# Spike2bBarcode15 0
# Spike2bUnclassified 80
# Spike3Barcode11 0
# Spike3Barcode13 0
# Spike3Barcode14 0
# Spike3Barcode15 0
# Spike3Unclassified 0
# Spike3bBarcode10 25
# Spike3bBarcode12 70
# Spike3bBarcode11 79
# Spike3bBarcode13 0
# Spike3bBarcode14 0
# Spike3bUnclassified 0
# Spike3bBarcode15 0
# Spike4Barcode01 69
# Spike4Barcode02 0
# Spike4Barcode03 0
# Spike4Barcode04 0
# Spike4Barcode05 0
# Spike4Barcode07 0
# Spike4Barcode08 0
# Spike4Barcode10 0
# Spike4Barcode11 0
# Spike4Barcode12 0
# Spike4Barcode13 0
# Spike4Barcode14 0
# Spike4Barcode15 0
# Spike4Barcode16 0
# Spike4Unclassified 0
# too many datasets with that name
# Spike1Barcode10 5
# Spike1Barcode11 0
# Spike1Barcode12 0
# Spike1Barcode13 0
# Spike1Barcode14 0
# Spike1Barcode15 0
#  Spike2Barcode10 6
# Spike2Barcode11 0
# Spike2Barcode12 0
# Spike2Barcode13 0
# Spike2Barcode14 0
# Spike2Barcode15 0
# Spike2bBarcode10 4
# Spike2bBarcode11 0
# Spike2bBarcode12 0
# Spike2bBarcode13 0
# Spike2bBarcode14 0
# Spike2bBarcode15 0
# Spike2bUnclassified 5
# Spike3Barcode11 0
# Spike3Barcode13 0
# Spike3Barcode14 0
# Spike3Barcode15 0
# Spike3Unclassified 0
# Spike3bBarcode10 0
# Spike3bBarcode12 0
# Spike3bBarcode11 0
# Spike3bBarcode13 0
# Spike3bBarcode14 0
# Spike3bUnclassified 0
# Spike3bBarcode15 0
# Spike4Barcode01 3
# Spike4Barcode02 3
# Spike4Barcode03 0
# Spike4Barcode04 0
# Spike4Barcode05 0
# Spike4Barcode07 0
# Spike4Barcode08 0
# Spike4Barcode10 0
# Spike4Barcode11 0
# Spike4Barcode12 0
# Spike4Barcode13 0
# Spike4Barcode14 0
# Spike4Barcode15 0
# Spike4Barcode16 0
# Spike4Unclassified 0

# %%
frames = [VF_df, AMR_df]
merged_df = pd.concat(frames, axis = 1)

#from IPython.core.display import HTML
print(merged_df.to_string())
# Out:
#                      VFs  AMR
# Name
# Spike1Barcode10      121    5
# Spike1Barcode11       60    0
# Spike1Barcode12        0    0
# Spike1Barcode13        0    0
# Spike1Barcode14        0    0
# Spike1Barcode15        0    0
#  Spike2Barcode10     135    6
# Spike2Barcode11       97    0
# Spike2Barcode12       77    0
# Spike2Barcode13        0    0
# Spike2Barcode14        0    0
# Spike2Barcode15        0    0
# Spike2bBarcode10     175    4
# Spike2bBarcode11      97    0
# Spike2bBarcode12      84    0
# Spike2bBarcode13       0    0
# Spike2bBarcode14       0    0
# Spike2bBarcode15       0    0
# Spike2bUnclassified   80    5
# Spike3Barcode11        0    0
# Spike3Barcode13        0    0
# Spike3Barcode14        0    0
# Spike3Barcode15        0    0
# Spike3Unclassified     0    0
# Spike3bBarcode10      25    0
# Spike3bBarcode12      70    0
# Spike3bBarcode11      79    0
# Spike3bBarcode13       0    0
# Spike3bBarcode14       0    0
# Spike3bUnclassified    0    0
# Spike3bBarcode15       0    0
# Spike4Barcode01       69    3
# Spike4Barcode02        0    3
# Spike4Barcode03        0    0
# Spike4Barcode04        0    0
# Spike4Barcode05        0    0
# Spike4Barcode07        0    0
# Spike4Barcode08        0    0
# Spike4Barcode10        0    0
# Spike4Barcode11        0    0
# Spike4Barcode12        0    0
# Spike4Barcode13        0    0
# Spike4Barcode14        0    0
# Spike4Barcode15        0    0
# Spike4Barcode16        0    0
# Spike4Unclassified     0    0

# %% [markdown]
# # Map with metadata

# %%
meta_df = pd.read_excel(open('data/Foodborne pathogen detection paper - Data Analysis.xlsx', 'rb'), sheet_name='Biolytix') 
meta_df.set_index("Galaxy ID", inplace=True)
meta_df.index.name = "Name"
frames = [merged_df, meta_df]
result = pd.concat(frames, axis = 1)
# print(len(result.columns))
# print(len(meta_df.columns))

print(result.to_string())
# Out:
#                        VFs  AMR   Barcode No. DSM-Number  bx-number Lot-Number Data Sequencing Source Sequencing Date                                                                              Information                                 Expected Strain Deplition   CT Value               CFU Enrichment         Medium  Galaxy Analysis Date  History Link                                                                                                                                                                                                                                                                                                                                                                                                           Comments
# Name
# Spike1Barcode10      121.0  5.0    Barcode 10    DSM 554  3042821.0       0404               Biolytix      19.06.2022                                     Salmonella enterica subsp. Enterica spike+enrichment             Salmonella enterica subsp. Enterica       NaN        NaN               NaN        Yes        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Sp
Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode01       69.0  3.0           NaN        NaN        NaN        NaN                    NaN             NaN                                                                                      NaN                                             NaN       NaN        NaN               NaN        NaN            NaN                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode02        0.0  3.0           NaN        NaN        NaN        NaN                    NaN             NaN                                                                                      NaN                                             NaN       NaN        NaN               NaN        NaN            NaN                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode03        0.0  0.0           NaN        NaN        NaN        NaN                    NaN             NaN                                                                                      NaN                                             NaN       NaN        NaN               NaN        NaN            NaN                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode04        0.0  0.0           NaN        NaN        NaN        NaN                    NaN             NaN                                                                                      NaN                                             NaN       NaN        NaN               NaN        NaN            NaN                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode05        0.0  0.0           NaN        NaN        NaN        NaN                    NaN             NaN                                                                                      NaN                                             NaN       NaN        NaN               NaN        NaN            NaN                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode07        0.0  0.0           NaN        NaN        NaN        NaN                    NaN             NaN                                                                                      NaN                                             NaN       NaN        NaN               NaN        NaN            NaN                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode08        0.0  0.0           NaN        NaN        NaN        NaN                    NaN             NaN                                                                                      NaN                                             NaN       NaN        NaN               NaN        NaN            NaN                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode10        0.0  0.0     Barcode10        NaN        NaN        NaN               Biolytix      30.11.2022    Salmonella enterica subsp. Salamae spike to chicken 2.1x10^3 CFU (1+E4 dilution step)              Salmonella enterica subsp. Salamae       NaN  34.205031               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode11        0.0  0.0     Barcode11        NaN        NaN        NaN               Biolytix      30.11.2022    Salmonella enterica subsp. Salamae spike to chicken 2.2x10^2 CFU (1+E5 dilution step)              Salmonella enterica subsp. Salamae       NaN  41.046125               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode12        0.0  0.0     Barcode12        NaN        NaN        NaN               Biolytix      30.11.2022          Salmonella enterica subsp. Salamae spike to chicken 10 CFU (1+E6 dilution step)              Salmonella enterica subsp. Salamae       NaN  36.206758               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode13        0.0  0.0     Barcode13        NaN        NaN        NaN               Biolytix      30.11.2022          Mix 1 (1:1:10):  1x S.Houtenea + 1x S.enterica + 10x S.Salamae spike to chicken  1x S.Houtenea + 1x S.enterica + 10x S.Salamae        NaN        NaN               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode14        0.0  0.0     Barcode14        NaN        NaN        NaN               Biolytix      30.11.2022          Mix 2 (1:10:1):  1x S.Houtenea + 10x S.enterica + 1x S.Salamae spike to chicken  1x S.Houtenea + 10x S.enterica + 1x S.Salamae        NaN        NaN               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode15        0.0  0.0     Barcode15        NaN        NaN        NaN               Biolytix      30.11.2022          Mix 3 (10:1:1):  10x S.Houtenea + 1x S.enterica + 1x S.Salamae spike to chicken  10x S.Houtenea + 1x S.enterica + 1x S.Salamae        NaN        NaN               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode16        0.0  0.0     Barcode16        NaN        NaN        NaN               Biolytix      30.11.2022            Mix 4 (5:5:5):  5x S.Houtenea + 5x S.enterica + 5x S.Salamae spike to chicken    5x S.Houtenea + 5x S.enterica + 5x S.Salamae       NaN        NaN               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Unclassified     0.0  0.0           NaN        NaN        NaN        NaN                    NaN             NaN                                                                                      NaN                                             NaN       NaN        NaN               NaN        NaN            NaN                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Pure1Barcode1          NaN  NaN     Barcode 1   DSM 9221  3042819.0       0517               Biolytix      17.02.2022                                                  Salmonella enterica subsp. Houtenae (1)             Salmonella enterica subsp. Houtenae       NaN        NaN               NaN        NaN  Pure Pathogen                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Pure1Barcode2          NaN  NaN     Barcode 2    DSM 554  3042821.0       0404               Biolytix      17.02.2022                                                  Salmonella enterica subsp. Enterica (4)             Salmonella enterica subsp. Enterica       NaN        NaN               NaN        NaN  Pure Pathogen                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Pure1Barcode3          NaN  NaN     Barcode 3   DSM 9220  3042820.0       0116               Biolytix      17.02.2022                                                   Salmonella enterica subsp. Salamae (2)              Salmonella enterica subsp. Salamae       NaN        NaN               NaN        NaN  Pure Pathogen                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Pure1Barcode4          NaN  NaN     Barcode 4   DSM 4688  3042825.0          -               Biolytix      17.02.2022                                                   Campylobacter jejuni subsp. Jejuni (3)              Campylobacter jejuni subsp. Jejuni       NaN  27.000000       1020CFU/ml         NaN  Pure Pathogen                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Pure1Barcode5          NaN  NaN     Barcode 5   DSM 4689  3042826.0       0219               Biolytix      17.02.2022                                                                   Campylobacter coli (7)                             Campylobacter coli        NaN        NaN               NaN        NaN  Pure Pathogen                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Pure1Barcode6          NaN  NaN     Barcode 6  DSM 11375  3042827.0       1219               Biolytix      17.02.2022                                                                   Campylobacter coli (7)                             Campylobacter coli        NaN        NaN               NaN        NaN  Pure Pathogen                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Pure1Barcode7          NaN  NaN     Barcode 7  DSM 20600  3042822.0       1020               Biolytix      17.02.2022                                                         Listeria monocytogenes (5) 20600                          Listeria monocytogenes       NaN        NaN               NaN        NaN  Pure Pathogen                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Pure1Barc
NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode1         NaN  NaN      Barcode1    DSM 554  3042821.0       0404               Biolytix      30.11.2022  Salmonella enterica subsp. Enterica spike to chicken 1.2x10^6 CFU (1:E+3 dilution step)             Salmonella enterica subsp. Enterica       NaN  15.956588               NaN        NaN        Chicken                   NaN           NaN  - Preparation of all samples: chicken meat spiked with different CFU of salmonella (for the 3 species),\n- CFU have been determined by classical microbiology colony counting in different dilutions,\n- no microbiological enrichment after spiking,\n- DNA extraction and library prep as in previous experiments,\n- last 4 samples were mixtures of the three salmonella species in different concentration
# Spike4Barcode2         NaN  NaN      Barcode2        NaN        NaN        NaN               Biolytix      30.11.2022  Salmonella enterica subsp. Enterica spike to chicken 2.9x10^5 CFU (1:E+4 dilution step)             Salmonella enterica subsp. Enterica       NaN  18.498361               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode3         NaN  NaN      Barcode3        NaN        NaN        NaN               Biolytix      30.11.2022  Salmonella enterica subsp. Enterica spike to chicken 5.3x10^4 CFU (1:E+5 dilution step)             Salmonella enterica subsp. Enterica       NaN  21.711907               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode4         NaN  NaN      Barcode4        NaN        NaN        NaN               Biolytix      30.11.2022  Salmonella enterica subsp. Enterica spike to chicken 1.4x10^3 CFU (1:E+6 dilution step)             Salmonella enterica subsp. Enterica       NaN  25.204560               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode5         NaN  NaN      Barcode5   DSM 9221  3042819.0       0517               Biolytix      30.11.2022   Salmonella enterica subsp. Houtenae spike to chicken 6.1x10^5 CFU (1:E3 dilution step)             Salmonella enterica subsp. Houtenae       NaN  24.801300               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode6         NaN  NaN      Barcode6        NaN        NaN        NaN               Biolytix      30.11.2022  Salmonella enterica subsp. Houtenae spike to chicken  6.8x10^4 CFU (1:E4 dilution step)             Salmonella enterica subsp. Houtenae       NaN  28.387662               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode7         NaN  NaN      Barcode7        NaN        NaN        NaN               Biolytix      30.11.2022  Salmonella enterica subsp. Houtenae spike to chicken  6.8x10^3 CFU (1:E5 dilution step)             Salmonella enterica subsp. Houtenae       NaN  32.131811               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode8         NaN  NaN      Barcode8        NaN        NaN        NaN               Biolytix      30.11.2022    Salmonella enterica subsp. Houtenae spike to chicken  8x10^2 CFU (1:E6 dilution step)             Salmonella enterica subsp. Houtenae       NaN  46.656800               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Barcode9         NaN  NaN      Barcode9   DSM 9220  3042820.0       0116               Biolytix      30.11.2022    Salmonella enterica subsp. Salamae spike to chicken 2.4x10^4 CFU (1+E3 dilution step)              Salmonella enterica subsp. Salamae       NaN  30.973821               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# Spike4Unclassifed      NaN  NaN  Unclassified        NaN        NaN        NaN               Biolytix      30.11.2022                                                                                      NaN                                             NaN       NaN        NaN               NaN        NaN        Chicken                   NaN           NaN                                                                                                                                                                                                                                                                                                                                                                                                                NaN

# %% [markdown]
# # plot it

# %%
import matplotlib.pyplot as plt
import numpy as np

selection = result[(result["AMR"] != 0) | (result["VFs"] != 0)]
selection = selection.dropna(subset = ["AMR","VFs"])

#print(selection["Enrichment"])
#print(selection.columns)
selection.set_index(["Enrichment"], drop=True, inplace = True)
#print(selection)
selection.plot( kind = "bar",
                #x = ["Enrichment"],
                y = ["AMR","VFs"], 
                figsize=(10,6), 
                )
plt.show()
