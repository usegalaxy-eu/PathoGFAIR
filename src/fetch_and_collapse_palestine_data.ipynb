# %% [markdown]
# # This notebook does:
# * moves each `crop` folder from the library https://usegalaxy.eu/libraries/folders/F70e3e2cca6d50fdb/page/1 into a history
# * combines the files into one collection
# * collapse the collection
# * rename the created file to the name of the barcode of the folder
# * combines all files into one collection

# %%
from bioblend.galaxy import GalaxyInstance
from bioblend.galaxy import dataset_collections as collections
import pandas as pd
from io import StringIO
import os
import requests

# %%
# %env GALAXY_API_KEY=cf4092f19ab187b157fea51f97f2791b
# Out:
# env: GALAXY_API_KEY=cf4092f19ab187b157fea51f97f2791b

# %%
gi = GalaxyInstance(url='https://usegalaxy.eu/', key=os.environ['GALAXY_API_KEY'])

# %% [markdown]
# ### Run the fetch, combine, collapse, combine pipeline

# %%
# paths and variables
h_name = 'collection_palestine_v2'
look_for = ("/crop/") #this needs to be a unique text part that can be used to match the folder path in the library
library_name = "Palestine"
output_collection = "palestine_data"

# create history with name
histories = gi.histories.get_histories(name = h_name)
if not histories:
    history_params = gi.histories.create_history(h_name)
    history_id = history_params["id"]
elif len(histories) > 1:
    raise ValueError('Too many histories with that name')
else:
    history_id = histories[0]["id"]

print(f"Storing data in history with ID: {history_id}")

# get all folders form a library
library_id = gi.libraries.get_libraries(name = library_name)[0]['id']
folders = gi.libraries.get_folders(library_id = library_id)

# get specific folders based on look_for text match
folder_ids = {}
for folder in folders:
    folder_path = folder['name']
    if look_for in folder_path:
        folder_id = folder['id']
        folder_name = folder_path.split('/')[-1] #we will use the name of the folder as name of the created collapsed file
        folder_ids[folder_name] = folder_id

#copy and collapse all folders into files in the history
collapsed_collection_ids = {}
for folder_name, folder_id in folder_ids.items():
    print(f"Processing folder with name: {folder_name}, id:{folder_id}")

    #copy complete folder
    copied_dataset = gi.histories.copy_dataset(history_id, folder_id, source = "library_folder")

    #create collection
    elements = []
    for dataset in copied_dataset:
        elements.append(collections.HistoryDatasetElement(name=dataset["name"], id=dataset["id"]))

    collection_response = gi.histories.create_dataset_collection(
                history_id=history_id,
                collection_description=collections.CollectionDescription(
                    name=folder_name,
                    type="list",
                    elements=elements
                )
        )

    #collapse collection using the collapse_dataset tool
    collection_id = collection_response["id"]

    tool_model = gi.tools.build(tool_id="toolshed.g2.bx.psu.edu/repos/nml/collapse_collections/collapse_dataset/5.1.0", history_id=history_id)
    template_inputs = tool_model["state_inputs"]

    template_inputs['input_list']['values'][0]['id'] = collection_id
    template_inputs['input_list']['values'][0]['src'] = "hdca" #optional possible input values can be seen by inspecting the tool_model, that showed hdca for the collections

    output = gi.tools.run_tool(tool_id="toolshed.g2.bx.psu.edu/repos/nml/collapse_collections/collapse_dataset/5.1.0", 
                    history_id=history_id, 
                    tool_inputs=template_inputs)
    
    id_of_created_dataset = output["outputs"][0]['id']   

    collapsed_collection_ids[folder_name] = id_of_created_dataset

    #update name
    gi.histories.update_dataset(history_id, id_of_created_dataset, name = folder_name)

#create collection of all datasets
elements = []
for dataset_name, dataset_id in collapsed_collection_ids.items():
    elements.append(collections.HistoryDatasetElement(name=dataset_name, id=dataset_id))

collection_response = gi.histories.create_dataset_collection(
            history_id=history_id,
            collection_description=collections.CollectionDescription(
                name=output_collection,
                type="list",
                elements=elements
            )
    )
# Out:
# Processing folder with name: barcode01, id:F8963227bea76f224
# Processing folder with name: barcode02, id:F584def5b593281ed
# Processing folder with name: barcode03, id:F451b3772c539bfbd
# Processing folder with name: barcode04, id:F648bdd4267ba3213
# Processing folder with name: barcode05, id:F75a6ad5e53c5e04d
# Processing folder with name: barcode06, id:Ffe330413467dea14
# Processing folder with name: barcode07, id:Fb2ce532c14359a8b
# Processing folder with name: barcode08, id:Fe370648cce1dd14b
# Processing folder with name: barcode09, id:Fcd0dff06735c1bbe
# Processing folder with name: barcode10, id:F1372e67d2434c48c
# Processing folder with name: barcode11, id:Fc87c6570a685d50b
# Processing folder with name: barcode12, id:Ff0c01f0d894bf716
# Processing folder with name: barcode13, id:Ff505f004a4df4d19
# Processing folder with name: barcode14, id:F6286e1a8443b2953
# Processing folder with name: barcode15, id:Fad5ea92260a13762
# Processing folder with name: barcode16, id:F3380e5303529b049
# Processing folder with name: barcode17, id:Fbca5c0ef5444719f
# Processing folder with name: barcode18, id:F8c1fc2d0ad94879c
# Processing folder with name: barcode19, id:F1e7405337c56f7e8
# Processing folder with name: barcode20, id:F1e21134b7363576d
# Processing folder with name: barcode21, id:Fac430c368931088b
# Processing folder with name: barcode22, id:F8188e350a6316d86
# Processing folder with name: barcode23, id:F74cab2ce6c0fba30
# Processing folder with name: barcode24, id:Fd8717b608fa9a645
# Processing folder with name: barcode25, id:F917ee55f2e40d8c2
# Processing folder with name: barcode26, id:F5576ff34d5724201
# Processing folder with name: barcode27, id:F2c025bea137588ea
# Processing folder with name: barcode28, id:Fe890cebbec37aff5
# Processing folder with name: barcode29, id:F5cd167ed9e159e73
# Processing folder with name: barcode30, id:F3b717623054d5125
# Processing folder with name: barcode31, id:Faf33da993dce5dd9
# Processing folder with name: barcode32, id:Ffda34f66d378078f
# Processing folder with name: barcode33, id:Fba4b49e25e23d746
# Processing folder with name: barcode34, id:F40a320c052b39748
# Processing folder with name: barcode35, id:F1db088c26a64a566
# Processing folder with name: barcode36, id:Fe26831c203cb8095
# Processing folder with name: barcode37, id:F45f967f26377c8c4
# Processing folder with name: barcode38, id:F8f2d958cee428ca1
# Processing folder with name: barcode39, id:Fa99a7c00f569ed88
# Processing folder with name: barcode40, id:F03081039fbdf2c6d
# Processing folder with name: barcode41, id:Fdc92e0a34f035a9a
# Processing folder with name: barcode42, id:F056f61020bf9f7f9
# Processing folder with name: barcode43, id:Fe5f411ba4a45b5a9
# Processing folder with name: barcode44, id:F345b7121883e0ce6
# Processing folder with name: barcode45, id:Fc5eda11cfe43bf68
# Processing folder with name: barcode46, id:Fcb47758437d0251b
# Processing folder with name: barcode47, id:F472f1c45af2d1f2f
# Processing folder with name: barcode48, id:F280ade89cdf8d8b4
# Processing folder with name: barcode49, id:Fc6fe333dcfcfa687
# Processing folder with name: barcode50, id:F77b3da7e9e46ce0b
# Processing folder with name: barcode51, id:Ff4bc72835ba72fdd
# Processing folder with name: barcode52, id:F29f2bb3d4be39290
# Processing folder with name: barcode53, id:F60e99c771d46b842
# Processing folder with name: barcode54, id:F4e4a526c2350ac1b
# Processing folder with name: barcode55, id:F00ac97e359efd5ef
# Processing folder with name: barcode56, id:F594dc8b2f151d9c5
# Processing folder with name: barcode57, id:Ff9eacaf9ee2b27ef
# Processing folder with name: barcode58, id:Fea14da941f11c1c3
# Processing folder with name: barcode59, id:F59b3d374fb491420
# Processing folder with name: barcode60, id:F371f4db2ee8bf9b4
# Processing folder with name: barcode61, id:F91b224f879fbba68
# Processing folder with name: barcode62, id:F8717c69371d84c37
# Processing folder with name: barcode63, id:F6dbb7ce589bd62de
# Processing folder with name: barcode64, id:Fe1949ac09dbd395e
# Processing folder with name: barcode65, id:F1d6195392d5b8f9d
# Processing folder with name: barcode66, id:F1dcb54572c96e0f5
# Processing folder with name: barcode67, id:F1f9d03b4f53006d6
# Processing folder with name: barcode68, id:Fa81ff7b13068aaaf
# Processing folder with name: barcode69, id:F9dc824ac3b4d3d4c
# Processing folder with name: barcode70, id:F917a0298c311c3f1
# Processing folder with name: barcode71, id:Fddf22132efdad7b0
# Processing folder with name: barcode72, id:F40ffdc8a4beafd3f
# Processing folder with name: barcode73, id:F735446c840461ab3
# Processing folder with name: barcode74, id:F012ef53249dfe965
# Processing folder with name: barcode75, id:F7a27f3c5cb3ee085
# Processing folder with name: barcode76, id:Fbeae286c2dc8a6db
# Processing folder with name: barcode77, id:F15404d7d496d5dc6
# Processing folder with name: barcode78, id:F581d679795100fff
# Processing folder with name: barcode79, id:F95950f1fa5508a64
# Processing folder with name: barcode80, id:Fd98c398b9b4c647b
# Processing folder with name: barcode81, id:F874714ecbd89d6dd
# Processing folder with name: barcode82, id:F4fd546589ad29533
# Processing folder with name: barcode83, id:Fe4512b976db1058d
# Processing folder with name: barcode84, id:Fd46a204492121f4f
