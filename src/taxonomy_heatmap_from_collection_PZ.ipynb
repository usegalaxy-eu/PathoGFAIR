# %%
from bioblend.galaxy import GalaxyInstance
import pandas as pd
from io import StringIO
import os
import requests
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Add galaxy API key
# Add `GALAXY_API_KEY` from `https://usegalaxy.eu/user/api_key` via `export GALAXY_API_KEY="<key>"` or `%env  GALAXY_API_KEY=<key>` in jupyter

# %%
# %env GALAXY_API_KEY=cc8ab6117e2e58a8ca8ac12ce8680ed8
# Out:
# env: GALAXY_API_KEY=cc8ab6117e2e58a8ca8ac12ce8680ed8

# %% [markdown]
# # Get collection

# %%
history_id = "a90a5dd2a4c17493"
collection_name = "Kraken2 with PlusPF database output report"

gi = GalaxyInstance(url='https://usegalaxy.eu/', key=os.environ['GALAXY_API_KEY'])

datasets = gi.datasets.get_datasets(name = collection_name, history_id = history_id)

#print(datasets)

#fetch collection by name
if len(datasets) > 1:
    print("too many datasets with that name")

for dataset in datasets:
    if dataset['history_content_type']=='dataset_collection': #get only collections
        if dataset['job_state_summary']['all_jobs'] == dataset['job_state_summary']['ok']: #get only collections where all jobs are ok
            dataset_collection_id = dataset["id"]


# get data of the elements in the collection
collection = gi.dataset_collections.show_dataset_collection(dataset_collection_id = dataset_collection_id)
# Out:
# too many datasets with that name

# %% [markdown]
# # Download, parse and store elements in collection

# %%
dfs = []

for element in collection['elements']:

    element_name = element['element_identifier']

    print(element_name)
    element_id = element['object']['id']
    data = gi.datasets.download_dataset(element_id, maxwait = 3)
    df = pd.read_csv(StringIO(data.decode("utf-8")), sep="\t", header=None)

    # get only species
    df = df.loc[(df.iloc[:,3] == "S1")]

    #set taxa as index without space
    df.index = df.iloc[:,5].str.strip(" ")

    # get only abundance for the sample
    df = df.iloc[:,0]

    df.name = element_name

    dfs.append(df)
# Out:
# Spike1Barcode10
# Spike1Barcode11
# Spike1Barcode12
# Spike1Barcode13
# Spike1Barcode14
# Spike1Barcode15
#  Spike2Barcode10
# Spike2Barcode11
# Spike2Barcode12
# Spike2Barcode13
# Spike2Barcode14
# Spike2Barcode15
# Spike2bBarcode10
# Spike2bBarcode11
# Spike2bBarcode12
# Spike2bBarcode13
# Spike2bBarcode14
# Spike2bBarcode15
# Spike2bUnclassified
# Spike3Barcode11
# Spike3Barcode13
# Spike3Barcode14
# Spike3Barcode15
# Spike3Unclassified
# Spike3bBarcode10
# Spike3bBarcode12
# Spike3bBarcode11
# Spike3bBarcode13
# Spike3bBarcode14
# Spike3bUnclassified
# Spike3bBarcode15
# Spike4Barcode01
# Spike4Barcode02
# Spike4Barcode03
# Spike4Barcode04
# Spike4Barcode05
# Spike4Barcode07
# Spike4Barcode08
# Spike4Barcode10
# Spike4Barcode11
# Spike4Barcode12
# Spike4Barcode13
# Spike4Barcode14
# Spike4Barcode15
# Spike4Barcode16
# Spike4Unclassified

# %% [markdown]
# # Merge collection into one file

# %%
#taxa that do not exist in one of the dfs get filled with zero
main_df = pd.concat(dfs, join="outer", axis = 1)
main_df.fillna(0, inplace=True)

main_df.index.name = "Subspecies Relative Abundance [%]"

outpath = "data/output"
os.makedirs(outpath, exist_ok=True)

main_df.to_csv(os.path.join(outpath,"kraken_species_abundance_bio.csv"))

# %% [markdown]
# # Adjust data

# %%
outpath = "data/output"

#normalize
main_df = pd.read_csv(os.path.join(outpath,"kraken_species_abundance_bio.csv"), index_col=0)

# Normalize between 0 and 1
main_df = main_df.apply(lambda x: x/sum(x),axis = 0)
print(main_df.shape)

# remove species where for no sample more than 0.02 abundance is present
main_df = main_df.loc[(main_df>=0.01).any(axis=1)]

# species on X ?
main_df = main_df.transpose()
# Out:
# (68, 46)

# %% [markdown]
# # Modify metadata

# %%
# add metadata
meta_df = pd.read_excel(open('data/Foodborne pathogen detection paper - Data Analysis.xlsx', 'rb'), sheet_name='Biolytix Spiked') 
meta_df.set_index("Galaxy ID", inplace=True)
meta_df.index.name = "Name"

meta_df

# add enrichment table
def set_enrichment_tag(tag):
    if tag == "Yes":
        return("(enriched)")
    if tag == "No":
        return("(not enriched)")
    if tag == "":
        return("(undefined)")

meta_df["Enrichment Tag"] = meta_df["Enrichment"].apply(set_enrichment_tag)

# shorted experted strain
meta_df["Short Strain"] = meta_df["Expected Strain"].str.replace("Salmonella enterica subsp.", "S.")

# add CT to output
def ct_value(ct):
    try:
        return(f"CT: {int(ct)}")
    except:
        return(f"CT: NA")

meta_df["CT tag"] = meta_df["CT Value"].apply(ct_value)
meta_df

# add CFU to output
def cfu_value(cfu):
    try:
        int(cfu)
        number = '{:.1e}'.format(cfu)
        return(f"CFU: {number}")
    except:
        return(f"CFU: NA")

meta_df["CFU tag"] = meta_df["CFU"].apply(cfu_value)

# complete tag
meta_df["Sample Description"] = meta_df["Short Strain"] + "\n" + meta_df["Enrichment Tag"] + " " + meta_df["CT tag"] + " " + meta_df["CFU tag"]
meta_df
# Out:
# /home/paul/mambaforge/envs/galaxy-api/lib/python3.7/site-packages/ipykernel_launcher.py:20: FutureWarning: The default value of regex will change from True to False in a future version.
#                     Sample Barcode Number DSM-Number  bx-number  Lot-Number  \
# Name
# Spike1Barcode10        S01     Barcode 10    DSM 554  3042821.0       404.0
# Spike1Barcode11        S02     Barcode 11   DSM 9221  3042819.0       517.0
# Spike1Barcode12        S03     Barcode 12   DSM 9220  3042820.0       116.0
# Spike1Barcode13        S04     Barcode 13    DSM 554  3042821.0       404.0
# Spike1Barcode14        S05     Baecode 14   DSM 9221  3042819.0       517.0
# Spike1Barcode15        S06     Barcode 15   DSM 9220  3042820.0       116.0
#  Spike2Barcode10       S07     Barcode 10    DSM 554  3042821.0       404.0
# Spike2Barcode11        S08     Barcode 11   DSM 9221  3042819.0       517.0
# Spike2Barcode12        S09     Barcode 12   DSM 9220  3042820.0       116.0
# Spike2Barcode13        S10     Barcode 13    DSM 554  3042821.0       404.0
# Spike2Barcode14        S11     Baecode 14   DSM 9221  3042819.0       517.0
# Spike2Barcode15        S12     Barcode 15   DSM 9220  3042820.0       116.0
# Spike2bBarcode10       S13     Barcode 10    DSM 554  3042821.0       404.0
# Spike2bBarcode11       S14     Barcode 11   DSM 9221  3042819.0       517.0
# Spike2bBarcode12       S15     Barcode 12   DSM 9220  3042820.0       116.0
# Spike2bBarcode13       S16     Barcode 13    DSM 554  3042821.0       404.0
# Spike2bBarcode14       S17     Baecode 14   DSM 9221  3042819.0       517.0
# Spike2bBarcode15       S18     Barcode 15   DSM 9220  3042820.0       116.0
# Spike2bUnclassified    S19   Unclassified        NaN        NaN         NaN
# Spike3Barcode10        S20     Barcode 10    DSM 554  3042821.0       404.0
# Spike3Barcode11        S21     Barcode 11   DSM 9221  3042819.0       517.0
# Spike3Barcode12        S22     Barcode 12   DSM 9220  3042820.0       116.0
# Spike3Barcode13        S23     Barcode 13    DSM 554  3042821.0       404.0
# Spike3Barcode14        S24     Baecode 14   DSM 9221  3042819.0       517.0
# Spike3Barcode15        S25     Barcode 15   DSM 9220  3042820.0       116.0
# Spike3Unclassified     S26   Unclassified        NaN        NaN         NaN
# Spike3bBarcode10       S27     Barcode 10    DSM 554  3042821.0       404.0
# Spike3bBarcode11       S28     Barcode 11   DSM 9221  3042819.0       517.0
# Spike3bBarcode12       S29     Barcode 12   DSM 9220  3042820.0       116.0
# Spike3bBarcode13       S30     Barcode 13    DSM 554  3042821.0       404.0
# Spike3bBarcode14       S31     Baecode 14   DSM 9221  3042819.0       517.0
# Spike3bBarcode15       S32     Barcode 15   DSM 9220  3042820.0       116.0
# Spike3bUnclassified    S33   Unclassified        NaN        NaN         NaN
# Spike4Barcode01        S34      Barcode01    DSM 554  3042821.0       404.0
# Spike4Barcode02        S35      Barcode02        NaN        NaN         NaN
# Spike4Barcode03        S36      Barcode03        NaN        NaN         NaN
# Spike4Barcode04        S37      Barcode04        NaN        NaN         NaN
# Spike4Barcode05        S38      Barcode05   DSM 9221  3042819.0       517.0
# Spike4Barcode06        S39      Barcode06        NaN        NaN         NaN
# Spike4Barcode07        S40      Barcode07        NaN        NaN         NaN
# Spike4Barcode08        S41      Barcode08        NaN        NaN         NaN
# Spike4Barcode09        S42      Barcode09   DSM 9220  3042820.0       116.0
# Spike4Barcode10        S43      Barcode10        NaN        NaN         NaN
# Spike4Barcode11        S44      Barcode11        NaN        NaN         NaN
# Spike4Barcode12        S45      Barcode12        NaN        NaN         NaN
# Spike4Barcode13        S46      Barcode13        NaN        NaN         NaN
# Spike4Barcode14        S47      Barcode14        NaN        NaN         NaN
# Spike4Barcode15        S48      Barcode15        NaN        NaN         NaN
# Spike4Barcode16        S49      Barcode16        NaN        NaN         NaN
# Spike4Unclassified     S50   Unclassified        NaN        NaN         NaN
#
#                     Data Sequencing Source Sequencing Date  \
# Name
# Spike1Barcode10                   Biolytix      19.06.2022
# Spike1Barcode11                   Biolytix      19.06.2022
# Spike1Barcode12                   Biolytix      19.06.2022
# Spike1Barcode13                   Biolytix      19.06.2022
# Spike1Barcode14                   Biolytix      19.06.2022
# Spike1Barcode15                   Biolytix      19.06.2022
#  Spike2Barcode10                  Biolytix      14.07.2022
# Spike2Barcode11                   Biolytix      14.07.2022
# Spike2Barcode12                   Biolytix      14.07.2022
# Spike2Barcode13                   Biolytix      14.07.2022
# Spike2Barcode14                   Biolytix      14.07.2022
# Spike2Barcode15                   Biolytix      14.07.2022
# Spike2bBarcode10                  Biolytix      20.07.2022
# Spike2bBarcode11                Salmonella enterica subsp. Houtenae       NaN
# Spike2bBarcode12                 Salmonella enterica subsp. Salamae       NaN
# Spike2bBarcode13                Salmonella enterica subsp. Enterica       NaN
# Spike2bBarcode14                Salmonella enterica subsp. Houtenae       NaN
# Spike2bBarcode15                 Salmonella enterica subsp. Salamae       NaN
# Spike2bUnclassified                                             NaN       NaN
# Spike3Barcode10                 Salmonella enterica subsp. Enterica       Yes
# Spike3Barcode11                 Salmonella enterica subsp. Houtenae       Yes
# Spike3Barcode12                  Salmonella enterica subsp. Salamae       Yes
# Spike3Barcode13                 Salmonella enterica subsp. Enterica       Yes
# Spike3Barcode14                 Salmonella enterica subsp. Houtenae       Yes
# Spike3Barcode15                  Salmonella enterica subsp. Salamae       Yes
# Spike3Unclassified                                              NaN       Yes
# Spike3bBarcode10                Salmonella enterica subsp. Enterica        No
# Spike3bBarcode11                Salmonella enterica subsp. Houtenae        No
# Spike3bBarcode12                 Salmonella enterica subsp. Salamae        No
# Spike3bBarcode13                Salmonella enterica subsp. Enterica        No
# Spike3bBarcode14                Salmonella enterica subsp. Houtenae        No
# Spike3bBarcode15                 Salmonella enterica subsp. Salamae        No
# Spike3bUnclassified                                             NaN        No
# Spike4Barcode01                 Salmonella enterica subsp. Enterica       NaN
# Spike4Barcode02                 Salmonella enterica subsp. Enterica       NaN
# Spike4Barcode03                 Salmonella enterica subsp. Enterica       NaN
# Spike4Barcode04                 Salmonella enterica subsp. Enterica       NaN
# Spike4Barcode05                 Salmonella enterica subsp. Houtenae       NaN
# Spike4Barcode06                 Salmonella enterica subsp. Houtenae       NaN
# Spike4Barcode07                 Salmonella enterica subsp. Houtenae       NaN
# Spike4Barcode08                 Salmonella enterica subsp. Houtenae       NaN
# Spike4Barcode09                  Salmonella enterica subsp. Salamae       NaN
# Spike4Barcode10                  Salmonella enterica subsp. Salamae       NaN
# Spike4Barcode11                  Salmonella enterica subsp. Salamae       NaN
# Spike4Barcode12                  Salmonella enterica subsp. Salamae       NaN
# Spike4Barcode13      1x S.Houtenea + 1x S.enterica + 10x S.Salamae        NaN
# Spike4Barcode14      1x S.Houtenea + 10x S.enterica + 1x S.Salamae        NaN
# Spike4Barcode15      10x S.Houtenea + 1x S.enterica + 1x S.Salamae        NaN
# Spike4Barcode16        5x S.Houtenea + 5x S.enterica + 5x S.Salamae       NaN
# Spike4Unclassified                                              NaN       NaN
#
#                      ...  Enrichment   Medium Galaxy Analysis Date  \
# Name                 ...
# Spike1Barcode10      ...         Yes  Chicken                  NaN
# Spike1Barcode11      ...         Yes  Chicken                  NaN
# Spike1Barcode12      ...         Yes  Chicken                  NaN
# Spike1Barcode13      ...          No  Chicken                  NaN
# Spike1Barcode14      ...          No  Chicken                  NaN
# Spike1Barcode15      ...          No  Chicken                  NaN
#  Spike2Barcode10     ...         Yes  Chicken                  NaN
# Spike2Barcode11      ...         Yes  Chicken                  NaN
# Spike2Barcode12      ...         Yes  Chicken                  NaN
# Spike2Barcode13      ...          No  Chicken                  NaN
# Spike2Barcode14      ...          No  Chicken                  NaN
# Spike2Barcode15      ...          No  Chicken                  NaN
# Spike2bBarcode10     ...         Yes  Chicken                  NaN
# Spike2bBarcode11     ...         Yes  Chicken                  NaN
# Spike2bBarcode12     ...         Yes  Chicken                  NaN
# Spike2bBarcode13     ...          No  Chicken                  NaN
# Spike2bBarcode14     ...          No  Chicken                  NaN
# Spike2bBarcode15     ...          No  Chicken                  NaN
# Spike2bUnclassified  ...         NaN  Chicken                  NaN
# Spike3Barcode10      ...         Yes  Chicken                  NaN
# Spike3Barcode11      ...         Yes  Chicken                  NaN
# Spike3Barcode12      ...         Yes  Chicken                  NaN
# Spike3Barcode13      ...          No  Chicken                  NaN
# Spike3Barcode14      ...          No  Chicken                  NaN
# Spike3Barcode15      ...          No  Chicken                  NaN
# Spike3Unclassified   ...         NaN  Chicken                  NaN
# Spike3bBarcode10     ...         Yes  Chicken                  NaN
# Spike3bBarcode11     ...         Yes  Chicken                  NaN
# Spike3bBarcode12     ...         Yes  Chicken                  NaN
# Spike3bBarcode13     ...          No  Chicken                  NaN
# Spike3bBarcode14     ...          No  Chicken                  NaN
# Spike3bBarcode15     ...          No  Chicken                  NaN
# Spike3bUnclassified  ...         NaN  Chicken                  NaN
# Spike4Barcode01      ...          No  Chicken                  NaN
# Spike4Barcode02      ...          No  Chicken                  NaN
# Spike4Barcode03      ...          No  Chicken                  NaN
# Spike4Barcode04      ...          No  Chicken                  NaN
# Spike4Barcode05      ...          No  Chicken                  NaN
# Spike4Barcode06      ...          No  Chicken                  NaN
# Spike4Barcode07      ...          No  Chicken                  NaN
# Spike4Barcode08      ...          No  Chicken                  NaN
# Spike4Barcode09      ...          No  Chicken                  NaN
# Spike4Barcode10      ...          No  Chicken                  NaN
# Spike4Barcode11      ...          No  Chicken                  NaN
# Spike4Barcode12      ...          No  Chicken                  NaN
# Spike4Barcode13      ...          No  Chicken                  NaN
# Spike4Barcode14      ...          No  Chicken                  NaN
# Spike4Barcode15      ...          No  Chicken                  NaN
# Spike4Barcode16      ...          No  Chicken                  NaN
# Spike4Unclassified   ...         NaN  Chicken                  NaN
#
#                     History Link  \
# Name
# Spike1Barcode10              NaN
# Spike1Barcode11              NaN
# Spike1Barcode12              NaN
# Spike1Barcode13              NaN
# Spike1Barcode14              NaN
# Spike1Barcode15              NaN
#  Spike2Barcode10             NaN
# Spike2Barcode11              NaN
# Spike2Barcode12              NaN
# Spike2Barcode13              NaN
# Spike2Barcode14              NaN
# Spike2Barcode15              NaN
# Spike2bBarcode10             NaN
# Spike2bBarcode11             NaN
# Spike2bBarcode12             NaN
# Spike2bBarcode13             NaN
# Spike2bBarcode14             NaN
# Spike2bBarcode15             NaN
# Spike2bUnclassified          NaN
# Spike3Barcode10              NaN
# Spike3Barcode11              NaN
# Spike3Barcode12              NaN
# Spike3Barcode13              NaN
# Spike3Barcode14              NaN
# Spike3Barcode15              NaN
# Spike3Unclassified           NaN
# Spike3bBarcode10             NaN
# Spike3bBarcode11             NaN
# Spike3bBarcode12             NaN
# Spike3bBarcode13             NaN
# Spike3bBarcode14             NaN
# Spike3bBarcode15             NaN
# Spike3bUnclassified          NaN
# Spike4Barcode01              NaN
# Spike4Barcode02              NaN
# Spike4Barcode03              NaN
# Spike4Barcode04              NaN
# Spike4Barcode05              NaN
# Spike4Barcode06              NaN
# Spike4Barcode07              NaN
# Spike4Barcode08              NaN
# Spike4Barcode09              NaN
# Spike4Barcode10              NaN
# Spike4Barcode11              NaN
# Spike4Barcode12              NaN
# Spike4Barcode13              NaN
# Spike4Barcode14              NaN
# Spike4Barcode15              NaN
# Spike4Barcode16              NaN
# Spike4Unclassified           NaN
#
#                                                               Comments  \
# Name
# Spike1Barcode10                                                    NaN
# Spike1Barcode11                                                    NaN
# Spike1Barcode12                                                    NaN
# Spike1Barcode13                                                    NaN
# Spike1Barcode14                                                    NaN
# Spike1Barcode15                                                    NaN
#  Spike2Barcode10                                                   NaN
# Spike2Barcode11                                                    NaN
# Spike2Barcode12                                                    NaN
# Spike2Barcode13                                                    NaN
# Spike2Barcode14                                                    NaN
# Spike2Barcode15                                                    NaN
# Spike2bBarcode10                                                   NaN
# Spike2bBarcode11                                                   NaN
# Spike2bBarcode12                                                   NaN
# Spike2bBarcode13                                                   NaN
# Spike2bBarcode14                                                   NaN
# Spike2bBarcode15                                                   NaN
# Spike2bUnclassified                                                NaN
# Spike3Barcode10      During sequencing depletion of chicken sequenc...
# Spike3Barcode11                                                    NaN
# Spike3Barcode12                                                    NaN
# Spike3Barcode13                                                    NaN
# Spike3Barcode14                                                    NaN
# Spike3Barcode15                                                    NaN
# Spike3Unclassified                                                 NaN
# Spike3bBarcode10     During sequencing preferred sequencing salmone...
# Spike3bBarcode11                                                   NaN
# Spike3bBarcode12                                                   NaN
# Spike3bBarcode13                                                   NaN
# Spike3bBarcode14                                                   NaN
# Spike3bBarcode15                                                   NaN
# Spike3bUnclassified                                                NaN
# Spike4Barcode01      - Preparation of all samples: chicken meat spi...
# Spike4Barcode02                                                    NaN
# Spike4Barcode03                                                    NaN
# Spike4Barcode04                                                    NaN
# Spike4Barcode05                                                    NaN
# Spike4Barcode06                                                    NaN
# Spike4Barcode07                                                    NaN
# Spike4Barcode08                                                    NaN
# Spike4Barcode09                                                    NaN
# Spike4Barcode10                                                    NaN
# Spike4Barcode11                                                    NaN
# Spike4Barcode12                                                    NaN
# Spike4Barcode13                                                    NaN
# Spike4Barcode14                                                    NaN
# Spike4Barcode15                                                    NaN
# Spike4Barcode16                                                    NaN
# Spike4Unclassified                                                 NaN
#
#                      Enrichment Tag  \
# Name
# Spike1Barcode10          (enriched)
# Spike1Barcode11          (enriched)
# Spike1Barcode12          (enriched)
# Spike1Barcode13      (not enriched)
# Spike1Barcode14      (not enriched)
# Spike1Barcode15      (not enriched)
#  Spike2Barcode10         (enriched)
# Spike2Barcode11          (enriched)
# Spike2Barcode12          (enriched)
# Spike2Barcode13      (not enriched)
# Spike2Barcode14      (not enriched)
# Spike2Barcode15      (not enriched)
# Spike2bBarcode10         (enriched)
# Spike2bBarcode11         (enriched)
# Spike2bBarcode12         (enriched)
# Spike2bBarcode13     (not enriched)
# Spike2bBarcode14     (not enriched)
# Spike2bBarcode15     (not enriched)
# Spike2bUnclassified            None
# Spike3Barcode10          (enriched)
# Spike3Barcode11          (enriched)
# Spike3Barcode12          (enriched)
# Spike3Barcode13      (not enriched)
# Spike3Barcode14      (not enriched)
# Spike3Barcode15      (not enriched)
# Spike3Unclassified             None
# Spike3bBarcode10         (enriched)
# Spike3bBarcode11         (enriched)
# Spike3bBarcode12         (enriched)
# Spike3bBarcode13     (not enriched)
# Spike3bBarcode14     (not enriched)
# Spike3bBarcode15     (not enriched)
# Spike3bUnclassified            None
# Spike4Barcode01      (not enriched)
# Spike4Barcode02      (not enriched)
# Spike4Barcode03      (not enriched)
# Spike4Barcode04      (not enriched)
# Spike4Barcode05      (not enriched)
# Spike4Barcode06      (not enriched)
# Spike4Barcode07      (not enriched)
# Spike4Barcode08      (not enriched)
# Spike4Barcode09      (not enriched)
# Spike4Barcode10      (not enriched)
# Spike4Barcode11      (not enriched)
# Spike4Barcode12      (not enriched)
# Spike4Barcode13      (not enriched)
# Spike4Barcode14      (not enriched)
# Spike4Barcode15      (not enriched)
# Spike4Barcode16      (not enriched)
# Spike4Unclassified             None
#
#                                                        Short Strain  CT tag  \
# Name
# Spike1Barcode10                                         S. Enterica  CT: NA
# Spike1Barcode11                                         S. Houtenae  CT: 24
# Spike1Barcode12                                          S. Salamae  CT: 19
# Spike1Barcode13                                         S. Enterica  CT: NA
# Spike1Barcode14                                         S. Houtenae  CT: 27
# Spike1Barcode15                                          S. Salamae  CT: 29
#  Spike2Barcode10                                        S. Enterica  CT: 13
# Spike2Barcode11                                         S. Houtenae  CT: 21
# Spike2Barcode12                                          S. Salamae  CT: 18
# Spike2Barcode13                                         S. Enterica  CT: 28
# Spike2Barcode14                                         S. Houtenae  CT: 28
# Spike2Barcode15                                          S. Salamae  CT: 30
# Spike2bBarcode10                                        S. Enterica  CT: 13
# Spike2bBarcode11                                        S. Houtenae  CT: 21
# Spike2bBarcode12                                         S. Salamae  CT: 18
# Spike2bBarcode13                                        S. Enterica  CT: 28
# Spike2bBarcode14                                        S. Houtenae  CT: 28
# Spike2bBarcode15                                         S. Salamae  CT: 30
# Spike2bUnclassified                                             NaN  CT: NA
# Spike3Barcode10                                         S. Enterica  CT: 13
# Spike3Barcode11                                         S. Houtenae  CT: 21
# Spike3Barcode12                                          S. Salamae  CT: 18
# Spike3Barcode13                                         S. Enterica  CT: 28
# Spike3Barcode14                                         S. Houtenae  CT: 28
# Spike3Barcode15                                          S. Salamae  CT: 30
# Spike3Unclassified                                              NaN  CT: NA
# Spike3bBarcode10                                        S. Enterica  CT: 13
# Spike3bBarcode11                                        S. Houtenae  CT: 21
# Spike3bBarcode12                                         S. Salamae  CT: 18
# Spike3bBarcode13                                        S. Enterica  CT: 28
# Spike3bBarcode14                                        S. Houtenae  CT: 28
# Spike3bBarcode15                                         S. Salamae  CT: 30
# Spike3bUnclassified                                             NaN  CT: NA
# Spike4Barcode01                                         S. Enterica  CT: 15
# Spike4Barcode02                                         S. Enterica  CT: 18
# Spike4Barcode03                                         S. Enterica  CT: 21
# Spike4Barcode04                                         S. Enterica  CT: 25
# Spike4Barcode05                                         S. Houtenae  CT: 24
# Spike4Barcode06                                         S. Houtenae  CT: 28
# Spike4Barcode07                                         S. Houtenae  CT: 32
# Spike4Barcode08                                         S. Houtenae  CT: 46
# Spike4Barcode09                                          S. Salamae  CT: 30
# Spike4Barcode10                                          S. Salamae  CT: 34
# Spike4Barcode11                                          S. Salamae  CT: 41
# Spike4Barcode12                                          S. Salamae  CT: 36
# Spike4Barcode13      1x S.Houtenea + 1x S.enterica + 10x S.Salamae   CT: NA
# Spike4Barcode14      1x S.Houtenea + 10x S.enterica + 1x S.Salamae   CT: NA
# Spike4Barcode15      10x S.Houtenea + 1x S.enterica + 1x S.Salamae   CT: NA
# Spike4Barcode16        5x S.Houtenea + 5x S.enterica + 5x S.Salamae  CT: NA
# Spike4Unclassified                                              NaN  CT: NA
#
#                           CFU tag  \
# Name
# Spike1Barcode10           CFU: NA
# Spike1Barcode11      CFU: 5.8e+07
# Spike1Barcode12      CFU: 5.8e+08
# Spike1Barcode13           CFU: NA
# Spike1Barcode14      CFU: 5.8e+06
# Spike1Barcode15      CFU: 5.8e+05
#  Spike2Barcode10     CFU: 1.0e+12
# Spike2Barcode11      CFU: 1.1e+09
# Spike2Barcode12      CFU: 9.0e+07
# Spike2Barcode13      CFU: 1.2e+06
# Spike2Barcode14      CFU: 6.8e+04
# Spike2Barcode15      CFU: 2.4e+04
# Spike2bBarcode10     CFU: 1.0e+12
# Spike2bBarcode11     CFU: 1.1e+09
# Spike2bBarcode12     CFU: 9.0e+07
# Spike2bBarcode13     CFU: 1.2e+06
# Spike2bBarcode14     CFU: 6.8e+04
# Spike2bBarcode15     CFU: 2.4e+04
# Spike2bUnclassified       CFU: NA
# Spike3Barcode10      CFU: 1.0e+12
# Spike3Barcode11      CFU: 1.1e+09
# Spike3Barcode12      CFU: 9.0e+07
# Spike3Barcode13      CFU: 1.2e+06
# Spike3Barcode14      CFU: 6.8e+04
# Spike3Barcode15      CFU: 2.4e+04
# Spike3Unclassified        CFU: NA
# Spike3bBarcode10     CFU: 1.0e+12
# Spike3bBarcode11     CFU: 1.1e+09
# Spike3bBarcode12     CFU: 9.0e+07
# Spike3bBarcode13     CFU: 1.2e+06
# Spike3bBarcode14     CFU: 6.8e+04
# Spike3bBarcode15     CFU: 2.4e+04
# Spike3bUnclassified       CFU: NA
# Spike4Barcode01      CFU: 1.2e+06
# Spike4Barcode02      CFU: 2.9e+05
# Spike4Barcode03      CFU: 5.3e+04
# Spike4Barcode04      CFU: 1.4e+03
# Spike4Barcode05      CFU: 6.1e+05
# Spike4Barcode06      CFU: 6.8e+04
# Spike4Barcode07      CFU: 6.8e+03
# Spike4Barcode08      CFU: 8.1e+02
# Spike4Barcode09      CFU: 2.4e+04
# Spike4Barcode10      CFU: 2.1e+03
# Spike4Barcode11      CFU: 2.2e+02
# Spike4Barcode12      CFU: 1.0e+01
# Spike4Barcode13           CFU: NA
# Spike4Barcode14           CFU: NA
# Spike4Barcode15           CFU: NA
# Spike4Barcode16           CFU: NA
# Spike4Unclassified        CFU: NA
#
#                                                     Sample Description
# Name
# Spike1Barcode10                 S. Enterica\n(enriched) CT: NA CFU: NA
# Spike1Barcode11            S. Houtenae\n(enriched) CT: 24 CFU: 5.8e+07
# Spike1Barcode12             S. Salamae\n(enriched) CT: 19 CFU: 5.8e+08
# Spike1Barcode13             S. Enterica\n(not enriched) CT: NA CFU: NA
# Spike1Barcode14        S. Houtenae\n(not enriched) CT: 27 CFU: 5.8e+06
# Spike1Barcode15         S. Salamae\n(not enriched) CT: 29 CFU: 5.8e+05
#  Spike2Barcode10           S. Enterica\n(enriched) CT: 13 CFU: 1.0e+12
# Spike2Barcode11            S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09
# Spike2Barcode12             S. Salamae\n(enriched) CT: 18 CFU: 9.0e+07
# Spike2Barcode13        S. Enterica\n(not enriched) CT: 28 CFU: 1.2e+06
# Spike2Barcode14        S. Houtenae\n(not enriched) CT: 28 CFU: 6.8e+04
# Spike2Barcode15         S. Salamae\n(not enriched) CT: 30 CFU: 2.4e+04
# Spike2bBarcode10           S. Enterica\n(enriched) CT: 13 CFU: 1.0e+12
# Spike2bBarcode11           S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09
# Spike2bBarcode12            S. Salamae\n(enriched) CT: 18 CFU: 9.0e+07
# Spike2bBarcode13       S. Enterica\n(not enriched) CT: 28 CFU: 1.2e+06
# Spike2bBarcode14       S. Houtenae\n(not enriched) CT: 28 CFU: 6.8e+04
# Spike2bBarcode15        S. Salamae\n(not enriched) CT: 30 CFU: 2.4e+04
# Spike2bUnclassified                                                NaN
# Spike3Barcode10            S. Enterica\n(enriched) CT: 13 CFU: 1.0e+12
# Spike3Barcode11            S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09
# Spike3Barcode12             S. Salamae\n(enriched) CT: 18 CFU: 9.0e+07
# Spike3Barcode13        S. Enterica\n(not enriched) CT: 28 CFU: 1.2e+06
# Spike3Barcode14        S. Houtenae\n(not enriched) CT: 28 CFU: 6.8e+04
# Spike3Barcode15         S. Salamae\n(not enriched) CT: 30 CFU: 2.4e+04
# Spike3Unclassified                                                 NaN
# Spike3bBarcode10           S. Enterica\n(enriched) CT: 13 CFU: 1.0e+12
# Spike3bBarcode11           S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09
# Spike3bBarcode12            S. Salamae\n(enriched) CT: 18 CFU: 9.0e+07
# Spike3bBarcode13       S. Enterica\n(not enriched) CT: 28 CFU: 1.2e+06
# Spike3bBarcode14       S. Houtenae\n(not enriched) CT: 28 CFU: 6.8e+04
# Spike3bBarcode15        S. Salamae\n(not enriched) CT: 30 CFU: 2.4e+04
# Spike3bUnclassified                                                NaN
# Spike4Barcode01        S. Enterica\n(not enriched) CT: 15 CFU: 1.2e+06
# Spike4Barcode02        S. Enterica\n(not enriched) CT: 18 CFU: 2.9e+05
# Spike4Barcode03        S. Enterica\n(not enriched) CT: 21 CFU: 5.3e+04
# Spike4Barcode04        S. Enterica\n(not enriched) CT: 25 CFU: 1.4e+03
# Spike4Barcode05        S. Houtenae\n(not enriched) CT: 24 CFU: 6.1e+05
# Spike4Barcode06        S. Houtenae\n(not enriched) CT: 28 CFU: 6.8e+04
# Spike4Barcode07        S. Houtenae\n(not enriched) CT: 32 CFU: 6.8e+03
# Spike4Barcode08        S. Houtenae\n(not enriched) CT: 46 CFU: 8.1e+02
# Spike4Barcode09         S. Salamae\n(not enriched) CT: 30 CFU: 2.4e+04
# Spike4Barcode10         S. Salamae\n(not enriched) CT: 34 CFU: 2.1e+03
# Spike4Barcode11         S. Salamae\n(not enriched) CT: 41 CFU: 2.2e+02
# Spike4Barcode12         S. Salamae\n(not enriched) CT: 36 CFU: 1.0e+01
# Spike4Barcode13      1x S.Houtenea + 1x S.enterica + 10x S.Salamae ...
# Spike4Barcode14      1x S.Houtenea + 10x S.enterica + 1x S.Salamae ...
# Spike4Barcode15      10x S.Houtenea + 1x S.enterica + 1x S.Salamae ...
# Spike4Barcode16      5x S.Houtenea + 5x S.enterica + 5x S.Salamae\n...
# Spike4Unclassified                                                 NaN
#
# [50 rows x 22 columns]

# %% [markdown]
# # Merge meta and taxonomy data

# %%
main_df_columns = main_df.columns

frames = [main_df, meta_df]
result = pd.concat(frames, axis = 1)

result.set_index("Sample Description", inplace = True)

result = result.loc[:,main_df_columns]
result = result[result.index.notnull()]

print(result.shape)

result = result.dropna(axis = 0)

print(result.shape)
result
# Out:
# (46, 11)
# (34, 11)
# Subspecies Relative Abundance [%]                   Salmonella enterica subsp. enterica  \
# Sample Description
# S. Enterica\n(enriched) CT: NA CFU: NA                                         1.000000
# S. Houtenae\n(enriched) CT: 24 CFU: 5.8e+07                                    1.000000
# S. Salamae\n(enriched) CT: 19 CFU: 5.8e+08                                     0.053571
# S. Salamae\n(not enriched) CT: 29 CFU: 5.8e+05                                 0.000000
# S. Enterica\n(enriched) CT: 13 CFU: 1.0e+12                                    0.315789
# S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09                                    0.500000
# S. Salamae\n(enriched) CT: 18 CFU: 9.0e+07                                     0.500000
# S. Houtenae\n(not enriched) CT: 28 CFU: 6.8e+04                                0.000000
# S. Enterica\n(enriched) CT: 13 CFU: 1.0e+12                                    0.315789
# S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09                                    0.500000
# S. Salamae\n(enriched) CT: 18 CFU: 9.0e+07                                     1.000000
# S. Enterica\n(not enriched) CT: 28 CFU: 1.2e+06                                0.000000
# S. Houtenae\n(not enriched) CT: 28 CFU: 6.8e+04                                0.000000
# S. Salamae\n(not enriched) CT: 30 CFU: 2.4e+04                                 0.000000
# S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09                                    0.000000
# S. Enterica\n(not enriched) CT: 28 CFU: 1.2e+06                                0.000000
# S. Houtenae\n(not enriched) CT: 28 CFU: 6.8e+04                                0.000000
# S. Enterica\n(enriched) CT: 13 CFU: 1.0e+12                                    0.210526
# S. Salamae\n(enriched) CT: 18 CFU: 9.0e+07                                     0.333333
# S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09                                    0.500000
# S. Salamae\n(not enriched) CT: 30 CFU: 2.4e+04                                 0.000000
# S. Enterica\n(not enriched) CT: 15 CFU: 1.2e+06                                0.933333
# S. Enterica\n(not enriched) CT: 18 CFU: 2.9e+05                                0.666667
# S. Enterica\n(not enriched) CT: 21 CFU: 5.3e+04                                0.000000
# S. Enterica\n(not enriched) CT: 25 CFU: 1.4e+03                                0.000000
# S. Houtenae\n(not enriched) CT: 24 CFU: 6.1e+05                                0.000000
# S. Houtenae\n(not enriched) CT: 32 CFU: 6.8e+03                                0.000000
# S. Houtenae\n(not enriched) CT: 46 CFU: 8.1e+02                                0.000000
# S. Salamae\n(not enriched) CT: 34 CFU: 2.1e+03                                 0.000000
# S. Salamae\n(not enriched) CT: 36 CFU: 1.0e+01                                 0.000000
# 1x S.Houtenea + 1x S.enterica + 10x S.Salamae \...                             0.000000
# 1x S.Houtenea + 10x S.enterica + 1x S.Salamae \...                             0.100000
# 10x S.Houtenea + 1x S.enterica + 1x S.Salamae \...                             0.200000
# 5x S.Houtenea + 5x S.enterica + 5x S.Salamae\n(...                             0.142857
#
# Subspecies Relative Abundance [%]                   Salmonella enterica subsp. salamae  \
# Sample Description
# S. Enterica\n(enriched) CT: NA CFU: NA                                        0.000000
# S. Houtenae\n(enriched) CT: 24 CFU: 5.8e+07                                   0.000000
# S. Salamae\n(enriched) CT: 19 CFU: 5.8e+08                                    0.482143
# S. Salamae\n(not enriched) CT: 29 CFU: 5.8e+05                                0.000000
# S. Enterica\n(enriched) CT: 13 CFU: 1.0e+12                                   0.000000
# S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09                                   0.000000
# S. Salamae\n(enriched) CT: 18 CFU: 9.0e+07                                    0.000000
# S. Houtenae\n(not enriched) CT: 28 CFU: 6.8e+04                               0.000000
# S. Enterica\n(enriched) CT: 13 CFU: 1.0e+12                                   0.000000
# S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09                                   0.000000
# S. Salamae\n(enriched) CT: 18 CFU: 9.0e+07                                    0.000000
# S. Enterica\n(not enriched) CT: 28 CFU: 1.2e+06                               0.000000
# S. Houtenae\n(not enriched) CT: 28 CFU: 6.8e+04                               0.000000
# S. Salamae\n(not enriched) CT: 30 CFU: 2.4e+04                                0.000000
# S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09                                   0.000000
# S. Enterica\n(not enriched) CT: 28 CFU: 1.2e+06                               0.000000
# S. Houtenae\n(not enriched) CT: 28 CFU: 6.8e+04                               0.000000
# S. Enterica\n(enriched) CT: 13 CFU: 1.0e+12                                   0.000000
# S. Salamae\n(enriched) CT: 18 CFU: 9.0e+07                                    0.000000
# S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09                                   0.000000
# S. Salamae\n(not enriched) CT: 30 CFU: 2.4e+04                                0.000000
# S. Enterica\n(not enriched) CT: 15 CFU: 1.2e+06                               0.066667
# S. Enterica\n(not enriched) CT: 18 CFU: 2.9e+05                               0.000000
# S. Enterica\n(not enriched) CT: 21 CFU: 5.3e+04                               0.000000
# S. Enterica\n(not enriched) CT: 25 CFU: 1.4e+03
# S. Enterica\n(not enriched) CT: 25 CFU: 1.4e+03                                0.000000
# S. Houtenae\n(not enriched) CT: 24 CFU: 6.1e+05                                0.000000
# S. Houtenae\n(not enriched) CT: 32 CFU: 6.8e+03                                0.000000
# S. Houtenae\n(not enriched) CT: 46 CFU: 8.1e+02                                0.000000
# S. Salamae\n(not enriched) CT: 34 CFU: 2.1e+03                                 0.000000
# S. Salamae\n(not enriched) CT: 36 CFU: 1.0e+01                                 0.000000
# 1x S.Houtenea + 1x S.enterica + 10x S.Salamae \...                             0.000000
# 1x S.Houtenea + 10x S.enterica + 1x S.Salamae \...                             0.000000
# 10x S.Houtenea + 1x S.enterica + 1x S.Salamae \...                             0.000000
# 5x S.Houtenea + 5x S.enterica + 5x S.Salamae\n(...                             0.000000
#
# Subspecies Relative Abundance [%]                   Pseudomonas syringae UMAF0158
# Sample Description
# S. Enterica\n(enriched) CT: NA CFU: NA                                        0.0
# S. Houtenae\n(enriched) CT: 24 CFU: 5.8e+07                                   0.0
# S. Salamae\n(enriched) CT: 19 CFU: 5.8e+08                                    0.0
# S. Salamae\n(not enriched) CT: 29 CFU: 5.8e+05                                0.0
# S. Enterica\n(enriched) CT: 13 CFU: 1.0e+12                                   0.0
# S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09                                   0.5
# S. Salamae\n(enriched) CT: 18 CFU: 9.0e+07                                    0.0
# S. Houtenae\n(not enriched) CT: 28 CFU: 6.8e+04                               0.0
# S. Enterica\n(enriched) CT: 13 CFU: 1.0e+12                                   0.0
# S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09                                   0.5
# S. Salamae\n(enriched) CT: 18 CFU: 9.0e+07                                    0.0
# S. Enterica\n(not enriched) CT: 28 CFU: 1.2e+06                               0.0
# S. Houtenae\n(not enriched) CT: 28 CFU: 6.8e+04                               0.0
# S. Salamae\n(not enriched) CT: 30 CFU: 2.4e+04                                0.0
# S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09                                   0.0
# S. Enterica\n(not enriched) CT: 28 CFU: 1.2e+06                               0.0
# S. Houtenae\n(not enriched) CT: 28 CFU: 6.8e+04                               0.0
# S. Enterica\n(enriched) CT: 13 CFU: 1.0e+12                                   0.0
# S. Salamae\n(enriched) CT: 18 CFU: 9.0e+07                                    0.0
# S. Houtenae\n(enriched) CT: 21 CFU: 1.1e+09                                   0.5
# S. Salamae\n(not enriched) CT: 30 CFU: 2.4e+04                                0.0
# S. Enterica\n(not enriched) CT: 15 CFU: 1.2e+06                               0.0
# S. Enterica\n(not enriched) CT: 18 CFU: 2.9e+05                               0.0
# S. Enterica\n(not enriched) CT: 21 CFU: 5.3e+04                               0.0
# S. Enterica\n(not enriched) CT: 25 CFU: 1.4e+03                               0.0
# S. Houtenae\n(not enriched) CT: 24 CFU: 6.1e+05                               0.0
# S. Houtenae\n(not enriched) CT: 32 CFU: 6.8e+03                               0.0
# S. Houtenae\n(not enriched) CT: 46 CFU: 8.1e+02                               0.0
# S. Salamae\n(not enriched) CT: 34 CFU: 2.1e+03                                0.0
# S. Salamae\n(not enriched) CT: 36 CFU: 1.0e+01                                0.0
# 1x S.Houtenea + 1x S.enterica + 10x S.Salamae \...                            0.0
# 1x S.Houtenea + 10x S.enterica + 1x S.Salamae \...                            0.0
# 10x S.Houtenea + 1x S.enterica + 1x S.Salamae \...                            0.0
# 5x S.Houtenea + 5x S.enterica + 5x S.Salamae\n(...                            0.0

# %% [markdown]
# # Plot the clustermap

# %%
# plot
#from matplotlib import rcParams
sns.set(font_scale=1)

result = result.transpose()

# figure size in inches
#rcParams['figure.figsize'] = 20,20

#result = result.transpose()
# sns.heatmap(main_df, cmap = )
g = sns.clustermap(result, cmap="Reds", xticklabels=True, row_cluster=False, figsize=(20,15), cbar_pos=(0.75, 0.04, 0.05, 0.10), linewidths=2)
ax = g.ax_heatmap
ax.set_ylabel("")

# fig = g.get_figure()
plt.savefig(os.path.join(outpath, "clustermap_subspecies_relative_abundance_biolytix.svg"))
plt.savefig(os.path.join(outpath, "clustermap_subspecies_relative_abundance_biolytix.pdf"))
plt.savefig(os.path.join(outpath, "clustermap_subspecies_relative_abundance_biolytix.png"))

#setting the scale
# cbnorm = Normalize(vmin=0-0.5,vmax=5+0.5,clip=False) #setting the scale
# cb = plt.colorbar(cm.ScalarMappable(norm=cbnorm, cmap=newcmp),fraction=1,ax=ax_color,ticks=np.arange(6))
